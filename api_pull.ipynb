# %%
import requests

# %%
git_api = 'https://api.github.com/repos/pradeep-1004/git_API_test_dataset/contents/'

# %%
bronze_path = '/Volumes/parent_cata/git_pull/api_pull/dump'

# %%
response = requests.get(git_api)
files = response.json()

# %%
for item in files:

    if not item["name"].lower().endswith(".csv"):
        print("Skipping:", item["name"])
        continue

    print("Processing:", item["name"])

    df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(item["download_url"]))

# %%
target_path = f"{bronze_path}/{item['name'].replace('.csv', '')}"

df.write.format("delta").mode("overwrite").save(target_path)

print("Saved to git_api_pull:", target_path)
